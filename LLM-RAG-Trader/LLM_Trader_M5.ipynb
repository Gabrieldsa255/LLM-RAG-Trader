# %%
# ✅ Instalação (executar uma vez)
# %pip install -U langchain langchain-community langchain-ollama langchain-chroma pymupdf ccxt tqdm
# Out:
# Requirement already satisfied: langchain in c:\users\paulo\anaconda3\lib\site-packages (0.3.25)
# Requirement already satisfied: langchain-community in c:\users\paulo\anaconda3\lib\site-packages (0.3.25)
# Requirement already satisfied: langchain-ollama in c:\users\paulo\anaconda3\lib\site-packages (0.3.3)
# Requirement already satisfied: langchain-chroma in c:\users\paulo\anaconda3\lib\site-packages (0.2.4)
# Requirement already satisfied: pymupdf in c:\users\paulo\anaconda3\lib\site-packages (1.26.1)
# Requirement already satisfied: ccxt in c:\users\paulo\anaconda3\lib\site-packages (4.4.90)
# Requirement already satisfied: tqdm in c:\users\paulo\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in c:\users\paulo\anaconda3\lib\site-packages (from langchain) (0.3.65)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\paulo\anaconda3\lib\site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\paulo\anaconda3\lib\site-packages (from langchain) (0.3.45)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\paulo\anaconda3\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\paulo\anaconda3\lib\site-packages (from langchain) (2.0.34)
# Requirement already satisfied: requests<3,>=2 in c:\users\paulo\anaconda3\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\paulo\anaconda3\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-community) (8.2.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: ollama<1.0.0,>=0.4.8 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-ollama) (0.5.1)
# Requirement already satisfied: chromadb>=1.0.9 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-chroma) (1.0.12)
# Requirement already satisfied: setuptools>=60.9.0 in c:\users\paulo\anaconda3\lib\site-packages (from ccxt) (75.1.0)
# Requirement already satisfied: certifi>=2018.1.18 in c:\users\paulo\anaconda3\lib\site-packages (from ccxt) (2024.8.30)
# Requirement already satisfied: cryptography>=2.6.1 in c:\users\paulo\anaconda3\lib\site-packages (from ccxt) (43.0.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\paulo\anaconda3\lib\site-packages (from ccxt) (4.14.0)
# Requirement already satisfied: aiodns>=1.1.1 in c:\users\paulo\anaconda3\lib\site-packages (from ccxt) (3.5.0)
# Requirement already satisfied: yarl>=1.7.2 in c:\users\paulo\anaconda3\lib\site-packages (from ccxt) (1.20.1)
# Requirement already satisfied: colorama in c:\users\paulo\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: pycares>=4.9.0 in c:\users\paulo\anaconda3\lib\site-packages (from aiodns>=1.1.1->ccxt) (4.9.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: build>=1.0.3 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: fastapi==0.115.9 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\paulo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (4.10.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.55b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\paulo\anaconda3\lib\site-packages (from chromadb>=1.0.9->langchain-chroma) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in c:\users\paulo\anaconda3\lib\site-packages (from fastapi==0.115.9->chromadb>=1.0.9->langchain-chroma) (0.45.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\paulo\anaconda3\lib\site-packages (from cryptography>=2.6.1->ccxt) (1.17.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\paulo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\paulo\anaconda3\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\paulo\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\paulo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\paulo\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\paulo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\paulo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\paulo\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\paulo\anaconda3\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\paulo\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paulo\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paulo\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\paulo\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: pyproject_hooks in c:\users\paulo\anaconda3\lib\site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\paulo\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.21)
# Requirement already satisfied: anyio in c:\users\paulo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\paulo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\paulo\anaconda3\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\paulo\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.9->langchain-chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\paulo\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\paulo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\paulo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\paulo\anaconda3\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\paulo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\paulo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\paulo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\paulo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\paulo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\paulo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in c:\users\paulo\anaconda3\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\paulo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\paulo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\paulo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (5.29.5)
# Requirement already satisfied: sympy in c:\users\paulo\anaconda3\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.13.2)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.55b1 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (0.55b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.55b1 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (0.55b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (0.55b1)
# Requirement already satisfied: opentelemetry-util-http==0.55b1 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (0.55b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-instrumentation==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in c:\users\paulo\anaconda3\lib\site-packages (from opentelemetry-instrumentation-asgi==0.55b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.9->langchain-chroma) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\paulo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb>=1.0.9->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\paulo\anaconda3\lib\site-packages (from posthog>=2.4.0->chromadb>=1.0.9->langchain-chroma) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\paulo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\paulo\anaconda3\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\paulo\anaconda3\lib\site-packages (from tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (0.33.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\paulo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\paulo\anaconda3\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\paulo\anaconda3\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\paulo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\paulo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in c:\users\paulo\anaconda3\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\paulo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\paulo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\paulo\anaconda3\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (4.9.1)
# Requirement already satisfied: filelock in c:\users\paulo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\paulo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\paulo\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\paulo\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (0.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\paulo\anaconda3\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\paulo\anaconda3\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\paulo\anaconda3\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\paulo\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
# ✅ Carregamento do PDF
import pathlib
from langchain.document_loaders import PyMuPDFLoader

pdf_path = pathlib.Path(r"C:\Users\paulo\Downloads\Tradedocuments.pdf")
loader = PyMuPDFLoader(str(pdf_path))
documents = loader.load()
print(f"📄 Total de páginas: {len(documents)}")
# Out:
# 📄 Total de páginas: 2334

# %%
# ✅ Separação em chunks
from langchain.text_splitter import RecursiveCharacterTextSplitter


splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
docs = splitter.split_documents(documents)
print(f"📚 Total de chunks: {len(docs)}")
# Out:
# 📚 Total de chunks: 5033

# %%
from langchain_ollama import OllamaEmbeddings
from langchain_community.vectorstores import Chroma

embeddings = OllamaEmbeddings(model="llama3")
db = Chroma.from_documents(docs, embedding=embeddings, persist_directory="chroma_db")
db.persist()
print("✅ Embeddings salvos")
# Out:
# ✅ Embeddings salvos

# %%
# ✅ Função para consultar a LLM com RAG
from langchain.chains import RetrievalQA
from langchain_ollama import ChatOllama

def consultar_modelo(pergunta: str):
    retriever = db.as_retriever()
    chain = RetrievalQA.from_chain_type(
        llm=ChatOllama(model="llama3"),
        retriever=retriever
    )
    resposta = chain.run(pergunta)
    return resposta

# %%
# ✅ Buscar candles da Binance
import ccxt

def buscar_candles_binance(symbol="BTC/USDT", timeframe='5m', limit=50):
    binance = ccxt.binance()
    ohlcv = binance.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)
    return ohlcv

# %%
# ✅ Converter candles em texto técnico
def gerar_texto_candle(ohlcv):
    texto = ""
    for ts, o, h, l, c, v in ohlcv[-10:]:
        texto += f"Abertura: {o:.2f}, Fechamento: {c:.2f}, Máxima: {h:.2f}, Mínima: {l:.2f}\n"
    return texto

# %%
# !ollama pull llama3:8b
# Out:
# pulling manifest â ‹ pulling manifest â ™ pulling manifest â ¹ pulling manifest â ¸ pulling manifest â ¼ pulling manifest â ´ pulling manifest â ¦ pulling manifest â § pulling manifest
# pulling 6a0746a1ec1a: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–� 4.7 GB
# pulling 4fa551d4f938: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�  12 KB
# pulling 8ab4849b038c: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�  254 B
# pulling 577073ffcc6c: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�  110 B
# pulling 3f8eb4da87fa: 100% â–•â–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–ˆâ–�  485 B
# verifying sha256 digest
# writing manifest
# success

# %%
# !pip install python-binance
# Out:
# Collecting python-binance
#   Downloading python_binance-1.0.29-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests in c:\users\paulo\anaconda3\lib\site-packages (from python-binance) (2.32.3)
# Requirement already satisfied: six in c:\users\paulo\anaconda3\lib\site-packages (from python-binance) (1.16.0)
# Collecting dateparser (from python-binance)
#   Using cached dateparser-1.2.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: aiohttp in c:\users\paulo\anaconda3\lib\site-packages (from python-binance) (3.12.13)
# Requirement already satisfied: websockets in c:\users\paulo\anaconda3\lib\site-packages (from python-binance) (15.0.1)
# Collecting pycryptodome (from python-binance)
#   Downloading pycryptodome-3.23.0-cp37-abi3-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp->python-binance) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp->python-binance) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp->python-binance) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp->python-binance) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp->python-binance) (6.0.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp->python-binance) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\paulo\anaconda3\lib\site-packages (from aiohttp->python-binance) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in c:\users\paulo\anaconda3\lib\site-packages (from dateparser->python-binance) (2.9.0.post0)
# Collecting pytz>=2024.2 (from dateparser->python-binance)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27,>=2015.06.24 in c:\users\paulo\anaconda3\lib\site-packages (from dateparser->python-binance) (2024.9.11)
# Collecting tzlocal>=0.2 (from dateparser->python-binance)
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\paulo\anaconda3\lib\site-packages (from requests->python-binance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\paulo\anaconda3\lib\site-packages (from requests->python-binance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\paulo\anaconda3\lib\site-packages (from requests->python-binance) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\paulo\anaconda3\lib\site-packages (from requests->python-binance) (2024.8.30)
# Requirement already satisfied: tzdata in c:\users\paulo\anaconda3\lib\site-packages (from tzlocal>=0.2->dateparser->python-binance) (2023.3)
# Downloading python_binance-1.0.29-py2.py3-none-any.whl (130 kB)
# Using cached dateparser-1.2.1-py3-none-any.whl (295 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 10.9 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Installing collected packages: pytz, tzlocal, pycryptodome, dateparser, python-binance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
# Successfully installed dateparser-1.2.1 pycryptodome-3.23.0 python-binance-1.0.29 pytz-2025.2 tzlocal-5.3.1

# %%
from langchain_ollama import ChatOllama
from binance.client import Client
import pandas as pd
import datetime

# 🔧 Configurar conexão com Binance
API_KEY = "sua_api"
API_SECRET = "sua_secret"
client = Client(API_KEY, API_SECRET)

# 🔧 Função para buscar candles
def buscar_candles(symbol="BTCUSDT", interval="5m", limit=10):
    klines = client.get_klines(symbol=symbol, interval=interval, limit=limit)
    df = pd.DataFrame(klines, columns=[
        "timestamp", "open", "high", "low", "close", "volume",
        "close_time", "quote_asset_volume", "number_of_trades",
        "taker_buy_base_volume", "taker_buy_quote_volume", "ignore"
    ])
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit='ms')
    return df[["timestamp", "open", "high", "low", "close"]]

# ✅ Buscar dados reais dos três tempos gráficos
df_diario = buscar_candles(interval="1d", limit=1)
df_h1     = buscar_candles(interval="1h", limit=1)
df_m5     = buscar_candles(interval="5m", limit=5)

# ✅ Simular análise técnica básica
def analisar(df, ciclo_nome):
    open_ = float(df.iloc[-1]["open"])
    close = float(df.iloc[-1]["close"])
    high  = float(df.iloc[-1]["high"])
    low   = float(df.iloc[-1]["low"])
    direcao = "Alta" if close > open_ else "Baixa"
    suporte = round(low, 2)
    resistencia = round(high, 2)
    return f"Ciclo: Canal Estreito de {direcao}\nSuporte: {suporte}\nResistência: {resistencia}"

# ✅ Gerar info com base nos dados atuais
info = f"""
--- Gráfico Diário ---
{analisar(df_diario, 'Diário')}

--- Gráfico H1 ---
{analisar(df_h1, 'H1')}

--- Gráfico M5 ---
{analisar(df_m5, 'M5')}
Número de correções: 3
Topo/Fundo Duplo: Não
Falha de Rompimento: Não
Última vela é Marubozu: Não
"""

# ✅ Gerar candles recentes formatados
candles = "\n".join([
    f"Abertura: {row.open}, Fechamento: {row.close}, Máxima: {row.high}, Mínima: {row.low}"
    for _, row in df_m5.iterrows()
])

# ✅ Criar o prompt
prompt = f"""
Sou um trader utilizando price action. Todas as decisões são feitas no gráfico M5.

{info}

Candles recentes:
{candles}

Com base nisso, responda em português e de forma organizada:
1. Devo comprar, vender ou aguardar?
2. Qual o melhor horário para entrar?
3. Onde devo posicionar o stop loss e o alvo da operação?
"""

# ✅ Consultar modelo Ollama
modelo = ChatOllama(model="llama3")
resposta = modelo.invoke(prompt)

# ✅ Exibir a resposta limpa
print("📈 Resposta da LLM:\n")
print(resposta.content)

# %%
# !pip install MetaTrader5 pandas
# Out:
# Collecting MetaTrader5
#   Downloading MetaTrader5-5.0.5120-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Requirement already satisfied: pandas in c:\users\paulo\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.7 in c:\users\paulo\anaconda3\lib\site-packages (from MetaTrader5) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\paulo\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\paulo\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\paulo\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\paulo\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading MetaTrader5-5.0.5120-cp312-cp312-win_amd64.whl (50 kB)
# Installing collected packages: MetaTrader5
# Successfully installed MetaTrader5-5.0.5120

# %%
import MetaTrader5 as mt5
import pandas as pd
import datetime
from langchain_ollama import ChatOllama

# ✅ Inicializar conexão com MetaTrader 5
if not mt5.initialize():
    raise RuntimeError("❌ Falha ao conectar ao MetaTrader 5")

# ✅ Função para buscar candles no MT5
def buscar_candles_mt5(symbol="XAUUSD", timeframe=mt5.TIMEFRAME_M5, n=200):
    hoje = datetime.datetime.now()
    rates = mt5.copy_rates_from(symbol, timeframe, hoje, n)
    df = pd.DataFrame(rates)
    df['time'] = pd.to_datetime(df['time'], unit='s')
    df.rename(columns={'time': 'timestamp', 'open': 'open', 'high': 'high', 'low': 'low', 'close': 'close'}, inplace=True)
    return df[['timestamp', 'open', 'high', 'low', 'close']]

# ✅ Buscar dados dos três tempos gráficos
df_diario = buscar_candles_mt5(timeframe=mt5.TIMEFRAME_D1, n=1)
df_h1     = buscar_candles_mt5(timeframe=mt5.TIMEFRAME_H1, n=1)
df_m5     = buscar_candles_mt5(timeframe=mt5.TIMEFRAME_M5, n=5)

# ✅ Simulação de análise técnica simples
def analisar(df, ciclo_nome):
    open_ = float(df.iloc[-1]["open"])
    close = float(df.iloc[-1]["close"])
    high  = float(df.iloc[-1]["high"])
    low   = float(df.iloc[-1]["low"])
    direcao = "Alta" if close > open_ else "Baixa"
    suporte = round(low, 2)
    resistencia = round(high, 2)
    return f"Ciclo: Canal Estreito de {direcao}\nSuporte: {suporte}\nResistência: {resistencia}"

# ✅ Gerar informações de mercado
info = f"""
--- Gráfico Diário ---
{analisar(df_diario, 'Diário')}

--- Gráfico H1 --
{analisar(df_h1, 'H1')}

--- Gráfico M5 ---
{analisar(df_m5, 'M5')}
Número de correções: 3
Topo/Fundo Duplo: Não
Falha de Rompimento: Não
Última vela é Marubozu: Não
"""

# ✅ Formatar candles recentes
candles = "\n".join([
    f"Abertura: {row.open}, Fechamento: {row.close}, Máxima: {row.high}, Mínima: {row.low}"
    for _, row in df_m5.iterrows()
])

# ✅ Criar prompt para o modelo com chance em porcentagem
prompt = f"""
Sou um trader utilizando price action. Todas as decisões são feitas no gráfico M5.

{info}

Candles recentes:
{candles}

Com base nisso, responda em português e de forma organizada:
1. Devo comprar, vender ou aguardar?
2. Qual o melhor horário para entrar?
3. Onde devo posicionar o stop loss e o alvo da operação?
4. Qual a chance do trade dar certo? Responda em porcentagem (%).
5. Quanto tempo médio a operação deve demorar até atingir o alvo ou o stop?
"""

# ✅ Consultar modelo do Ollama
modelo = ChatOllama(model="llama3")
resposta = modelo.invoke(prompt)

# ✅ Exibir resposta
print("📈 Resposta da LLM:\n")
print(resposta.content)
# Out:
# 📈 Resposta da LLM:
#
# **Análise Price Action M5**
#
# 1. **Devo comprar, vender ou aguardar?**: Aguardar. O gráfico M5 está mostrando um canal estreito de baixa e não há uma oportunidade clara para compra ou venda.
# 2. **Qual o melhor horário para entrar?**: Nenhum é recomendado, pois a tendência atual é neutra e não há um momento específico que justifique uma operação.
# 3. **Onde devo posicionar o stop loss e o alvo da operação?**: Não há um ponto de entrada definido, portanto, não há como posicionar o stop loss e o alvo.
# 4. **Qual a chance do trade dar certo?**: Aproximadamente 50% (ou seja, indeterminado).
# 5. **Quanto tempo médio a operação deve demorar até atingir o alvo ou o stop?**: Não há um alvo definido e não há uma tendência clara para que possamos estimar um prazo.
#
# Observações adicionais:
#
# * O ciclo do gráfico M5 é um canal estreito de baixa, o que sugere uma tendência neutra.
# * A Suporte e a Resistência estão próximas entre si, o que também indica uma falta de impulso para compra ou venda.
# * Não há um Topo/Fundo Duplo nem Falha de Rompimento no gráfico M5, o que diminui a chance de uma operação dar certo.
